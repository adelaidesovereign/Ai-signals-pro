# %% [markdown]
# # Colab Quickstart
# Run the cell below to install dependencies and generate today's signals.

# %%
# !pip install -r requirements.txt
# !python cli.py today --mode swing --tickers SPY AAPL NVDA
